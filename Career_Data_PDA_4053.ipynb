# %% [markdown]
# ## CAREER_DATA

# %% [markdown]
# **The dataset is designed to analyse wheter the indiviulas changes their ocuupation based on some factors like academic background, job experince,Salary, and age**

# %%
# To import pandas and numpy and visulaization libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# To read Career data set excel file
career_data = pd.read_excel("/content/Career data_PDA_4053.xlsx")

# %%
# Checking the shape of dataset has 5000 Rows & 21 Columns
career_data.shape
# Out:
# (5000, 21)

# %%
# Dataset first 5 rows
career_data.head()
# Out:
#   Field of Study Current Occupation   Age  Gender  Years of Experience  \
# 0       Medicine   Business Analyst  48.0    Male                  7.0
# 1      Education          Economist  44.0    Male                 26.0
# 2      Education          Biologist  21.0  Female                 27.0
# 3      Education   Business Analyst  33.0    Male                 14.0
# 4           Arts             Doctor  28.0  Female                  0.0
#
#   Education Level Industry Growth Rate  Job Satisfaction  Work-Life Balance  \
# 0     High School                 High               7.0               10.0
# 1        Master's                  Low              10.0                3.0
# 2        Master's                  NaN               8.0                3.0
# 3             PhD               Medium               7.0                9.0
# 4             PhD                  Low               3.0                1.0
#
#    Job Opportunities  ... Job Security  Career Change Interest Skills Gap  \
# ...

# %%
career_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Field of Study               4999 non-null   object
#  1   Current Occupation           4996 non-null   object
#  2   Age                          4996 non-null   float64
#  3   Gender                       4993 non-null   object
#  4   Years of Experience          4998 non-null   float64
#  5   Education Level              4994 non-null   object
#  6   Industry Growth Rate         4995 non-null   object
#  7   Job Satisfaction             4998 non-null   float64
#  8   Work-Life Balance            4997 non-null   float64
#  9   Job Opportunities            4993 non-null   float64
#  10  Salary                       4994 non-null   object
#  11  Job Security                 4996 non-null   float64
# ...

# %%
# To check Career_Data set has null value
career_data.isnull().sum()
# Out:
# Field of Study                 1
# Current Occupation             4
# Age                            4
# Gender                         7
# Years of Experience            2
# Education Level                6
# Industry Growth Rate           5
# Job Satisfaction               2
# Work-Life Balance              3
# Job Opportunities              7
# Salary                         6
# Job Security                   4
# Career Change Interest         5
# Skills Gap                     5
# Certifications                 5
# Freelancing Experience         6
# Geographic Mobility            4
# Professional Networks          6
# Career Change Events           2
# Technology Adoption            4
# Likely to Change Occupation    1
# dtype: int64

# %%
 career_data = career_data.drop(['Industry Growth Rate','Job Satisfaction','Work-Life Balance',
                                'Job Security','Career Change Interest', 'Skills Gap','Certifications',
                                'Freelancing Experience', 'Geographic Mobility','Professional Networks',
                                'Career Change Events', 'Technology Adoption',
                                'Likely to Change Occupation'], axis=1)

# %%
career_data.columns
# Out:
# Index(['Field of Study', 'Current Occupation', 'Age', 'Gender',
#        'Years of Experience', 'Education Level', 'Job Opportunities',
#        'Salary'],
#       dtype='object')

# %%
# Tocheck the data is null or not
career_data.shape
career_data.isnull().sum()
# Out:
# Field of Study         1
# Current Occupation     4
# Age                    4
# Gender                 7
# Years of Experience    2
# Education Level        6
# Job Opportunities      7
# Salary                 6
# dtype: int64

# %% [markdown]
# To remove the outliners using univariant imputation by usin statical method Mean, Mode, Median. By using seaborn we can identify the outliner for Age,
# Years of Experience,Job Opportunities and salary.

# %%
#Convert selected columns to numeric properly
cols_to_convert = ['Age', 'Years of Experience', 'Job Opportunities', 'Salary']
for col in cols_to_convert:
    career_data[col] = pd.to_numeric(career_data[col], errors='coerce')

# %%
# To eremove NAN
career_data = career_data.dropna()

# %%
# After removing check whether the dataset is null
career_data.isnull().sum()
# Out:
# Field of Study         0
# Current Occupation     0
# Age                    0
# Gender                 0
# Years of Experience    0
# Education Level        0
# Job Opportunities      0
# Salary                 0
# dtype: int64

# %% [markdown]
# We will use mean() method as there is no outliners

# %%
plt.figure(figsize= (30,6))
plt.subplot(1, 4, 1)
sns.boxplot(career_data["Age"])
plt.subplot(1, 4, 2)
sns.boxplot(career_data["Years of Experience"])
plt.subplot(1, 4, 3)
sns.boxplot(career_data["Job Opportunities"])
plt.subplot(1, 4, 4)
sns.boxplot(career_data["Salary"])
plt.show()

# %% [markdown]
# Refer to above box plot outliners are seen on Salary column we are using median() method.
# For Age, Years of Experince, and Job oppurtunities use mean() method

# %%
# Mean() for Age
age_value = career_data["Age"].mean()
age_value
# Out:
# np.float64(39.36559356136821)

# %%
# Mean() for Years of Experince, and Job oppurtunities
yrs_experince = career_data["Years of Experience"].mean()
yrs_experince
# Out:
# np.float64(19.774849094567404)

# %%
# Mean() for job oppurtunities
job_oppurtunities = career_data["Job Opportunities"].mean()
job_oppurtunities
# Out:
# np.float64(50.616297786720324)

# %%
# To use fillna method for Age, Years of Experience and Job oppurtunities
career_data.loc[:, "Age"] = career_data["Age"].fillna(age_value)
career_data.loc[:, "Years of Experience"] = career_data["Years of Experience"].fillna(yrs_experince)
career_data.loc[:, "Job Opportunities"] = career_data["Job Opportunities"].fillna(job_oppurtunities)

# %%
career_data
# Out:
#               Field of Study Current Occupation   Age  Gender  \
# 0                   Medicine   Business Analyst  48.0    Male
# 1                  Education          Economist  44.0    Male
# 2                  Education          Biologist  21.0  Female
# 4                       Arts             Doctor  28.0  Female
# 5                   Medicine             Lawyer  56.0    Male
# ...                      ...                ...   ...     ...
# 4995                 Biology       Psychologist  51.0    Male
# 4996  Mechanical Engineering          Economist  35.0  Female
# 4997               Education             Doctor  30.0  Female
# 4998               Economics          Economist  38.0    Male
# 4999                    Arts          Biologist  26.0    Male
#
#       Years of Experience Education Level  Job Opportunities    Salary
# 0                     7.0     High School               83.0  198266.0
# 1                    26.0        Master's               55.0   96803.0
# ...

# %%
# In the process of fixing outliner with median()
median_salary = career_data['Salary'].median()

# %%
# To Use fillna method to fill the Salary
career_data.loc[:, "Salary"] = career_data["Salary"].fillna(median_salary)

# %%
# Using IQR method to identify the upper and lower limit in Salary
Q1 = career_data['Salary'].quantile(0.25) # Any value below 0.25 is outliners
Q3 = career_data['Salary'].quantile(0.75) # Any value above 0.75 is outliners
IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

#career_data = career_data[(career_data['Salary'] >= lower_limit) & (career_data['Salary'] <= upper_limit)]

# %%
# To fix outliner use clip method
career_data.loc[:, "Salary"] = career_data["Salary"].clip(lower_limit, upper_limit)

# %%
career_data.head()
# Out:
#   Field of Study Current Occupation   Age  Gender  Years of Experience  \
# 0       Medicine   Business Analyst  48.0    Male                  7.0
# 1      Education          Economist  44.0    Male                 26.0
# 2      Education          Biologist  21.0  Female                 27.0
# 4           Arts             Doctor  28.0  Female                  0.0
# 5       Medicine             Lawyer  56.0    Male                 39.0
#
#   Education Level  Job Opportunities    Salary
# 0     High School               83.0  198266.0
# 1        Master's               55.0   96803.0
# 2        Master's               78.0   65920.0
# 4             PhD                8.0   43986.0
# 5      Bachelor's               99.0  143252.0

# %% [markdown]
# Now to use encoding method for categogerical data, to convert to numerical data; before encoding use mode() method to fix the NAN in the data set columns of
# Field of Study, Current Occupation, Gender and	Education Level.

# %%
# To convert Gender value in to numeric
career_data = pd.get_dummies(career_data, columns=["Gender"], dtype="int64", drop_first=True)

# %%
# Check if 'Gender' column exists before encoding
if 'Gender' in career_data.columns:
    # To convert Gender value in to numeric
    career_data = pd.get_dummies(career_data, columns=["Gender"], dtype="int64", drop_first=True)
    print("One-hot encoding for 'Gender' applied.")
else:
    print("Error: 'Gender' column not found in the DataFrame.")
# Out:
# Error: 'Gender' column not found in the DataFrame.

# %%
career_data
# Out:
#               Field of Study Current Occupation   Age  Years of Experience  \
# 0                   Medicine   Business Analyst  48.0                  7.0
# 1                  Education          Economist  44.0                 26.0
# 2                  Education          Biologist  21.0                 27.0
# 4                       Arts             Doctor  28.0                  0.0
# 5                   Medicine             Lawyer  56.0                 39.0
# ...                      ...                ...   ...                  ...
# 4995                 Biology       Psychologist  51.0                  1.0
# 4996  Mechanical Engineering          Economist  35.0                 16.0
# 4997               Education             Doctor  30.0                  9.0
# 4998               Economics          Economist  38.0                  6.0
# 4999                    Arts          Biologist  26.0                 19.0
#
#      Education Level  Job Opportunities    Salary  Gender_Male
# ...

# %% [markdown]
# To fix the Ordinal columns Field of Study,	Current Occupation, Education Level

# %%
# Field of Study
field_study_encoding = {"Mechanical Engineering":1, "Psychology": 2, "Economics": 3,
                    "Arts": 4, "Computer Science" : 5, "Biology" : 6,
                    "Education" : 7, "Law" : 8, "Business" : 9, "Medicine":10}

# %%
# Use MAP method to encode the values
career_data["Field of Study"] = career_data["Field of Study"].map(field_study_encoding)

# %%
Current_Occupation_encoding = {"Mechanical Engineer":1, "Psychologist":2, "Teacher":3,
                               "Business Analyst":4, "Biologist":5, "Lawyer":6,
                               "Economist":7, "Artist":8, "Doctor":9,
                               "Software Developer":10}

# %%
career_data["Current Occupation"] = career_data["Current Occupation"].map(Current_Occupation_encoding)

# %%
career_data["Education Level"].value_counts()
# Out:
# Education Level
# High School    1251
# Bachelor's     1241
# Master's       1240
# PhD            1238
# Name: count, dtype: int64

# %%
education_level_encoding = {"High School":1, "Bachelor's":2,"Master's":3,"PhD":4}

# %%
career_data["Education Level"] = career_data["Education Level"].map(education_level_encoding)

# %%
#grouped = career_data.groupby('Field of Study')[['Age', 'Years of Experience', 'Job Opportunities', 'Salary']].mean()

# %%
# Step 1: Mapping Field of Study codes to names
field_labels = {
    1: "Mechanical Eng.",
    2: "Psychology",
    3: "Economics",
    4: "Arts",
    5: "Computer Sci.",
    6: "Biology",
    7: "Education",
    8: "Law",
    9: "Business",
    10: "Medicine"
}

# Step 2: Group by Field of Study and calculate mean values
grouped = career_data.groupby('Field of Study')[['Age', 'Years of Experience', 'Job Opportunities', 'Salary']].mean()

# Step 3: Replace numeric index with labels
grouped.index = grouped.index.map(field_labels)

# Step 4: Create 4 separate bar plots
fig, axes = plt.subplots(2, 2, figsize=(14,8))
metrics = ['Age', 'Years of Experience', 'Job Opportunities', 'Salary']

for i, col in enumerate(metrics):
    ax = axes[i//2, i%2]
    grouped[col].plot(kind='bar', ax=ax, color=plt.cm.tab10(i))
    ax.set_title(f'Average {col} by Field of Study', fontsize=11)
    ax.set_xlabel('Field of Study')
    ax.set_ylabel(f'Average {col}')
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
